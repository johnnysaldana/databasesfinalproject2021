# %%
import pandas as pd

# %% [markdown]
# We start off with Pandas Series, which are one dimensional array objects that can hold objects of varying data types. We, then will move onto pandas Dataframes, where we will cover loading in CSVs and all the other shit you do.

# %%
groceries = pd.Series(data = [30, 6, 'Yes', 'No'], index = ['eggs', 'apples', 'milk', 'bread'])
groceries
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
print('Groceries has shape:', groceries.shape)
print('Groceries has dimension:', groceries.ndim)
print('Groceries has a total of', groceries.size, 'elements')
# Out:
# Groceries has shape: (4,)
# Groceries has dimension: 1
# Groceries has a total of 4 elements

# %%
print('The data in Groceries is:', groceries.values)
print('The index of Groceries is:', groceries.index)
# Out:
# The data in Groceries is: [30 6 'Yes' 'No']
# The index of Groceries is: Index(['eggs', 'apples', 'milk', 'bread'], dtype='object')

# %%
print('How many eggs do we need to buy:', groceries['eggs'])
# Out:
# How many eggs do we need to buy: 30

# %%
print('Do we need milk and bread:\n', groceries[['milk', 'bread']])
# Out:
# Do we need milk and bread:
#  milk     Yes
# bread     No
# dtype: object

# %% [markdown]
# Pandas Series have two attributes, .loc and .iloc to explicitly state what we mean. The attribute .loc stands for location and it is used to explicitly state that we are using a labeled index. Similarly, the attribute .iloc stands for integer location and it is used to explicitly state that we are using a numerical index. Let's see some examples:

# %%
print('How many eggs and apples do we need to buy:\n', groceries.loc[['eggs', 'apples']])
# Out:
# How many eggs and apples do we need to buy:
#  eggs      30
# apples     6
# dtype: object

# %%
print('How many eggs and apples do we need to buy:\n',  groceries[[0, 1]])
# Out:
# How many eggs and apples do we need to buy:
#  eggs      30
# apples     6
# dtype: object

# %%
print('Do we need bread:\n', groceries[[-1]])
# Out:
# Do we need bread:
#  bread    No
# dtype: object

# %%
print('Do we need milk and bread:\n', groceries.iloc[[2, 3]])
# Out:
# Do we need milk and bread:
#  milk     Yes
# bread     No
# dtype: object

# %% [markdown]
# Pandas Series are also mutable like NumPy ndarrays, which means we can change the elements of a Pandas Series after it has been created.

# %%
print('Original Grocery List:\n', groceries)
# Out:
# Original Grocery List:
#  eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
groceries['eggs'] = 2
print('Modified Grocery List:\n', groceries)
# Out:
# Modified Grocery List:
#  eggs        2
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %% [markdown]
# We can also delete items from a Pandas Series by using the .drop() method. The Series.drop(label) method removes the given label from the given Series.

# %%
groceries.drop('apples')
# Out:
# eggs       2
# milk     Yes
# bread     No
# dtype: object

# %%
print(groceries) #Why is apples still there? It turns out when you drop, the original series is unaffected.
#to change the original series, set inplace = True
# Out:
# eggs        2
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
groceries.drop('apples', inplace = True)

# %%
print(groceries)
# Out:
# eggs       2
# milk     Yes
# bread     No
# dtype: object

# %% [markdown]
# ## Arithmetic Ops ##

# %%
grocery_list = pd.Series(data = [30, 6, 5, 10], index = ['eggs', 'apples', 'milk', 'bread'])
grocery_list
# Out:
# eggs      30
# apples     6
# milk       5
# bread     10
# dtype: int64

# %%
#add 2 more of each to grocery_list
print(grocery_list + 2)
#multiply by 2 
print("\n Multiplied List\n",grocery_list * 2)
# Out:
# eggs      32
# apples     8
# milk       7
# bread     12
# dtype: int64
#
#  Multiplied List
#  eggs      60
# apples    12
# milk      10
# bread     20
# dtype: int64

# %% [markdown]
# We can do the same math operations we did in numpy.

# %%
import numpy as np
np.power(grocery_list,2)
# Out:
# eggs      900
# apples     36
# milk       25
# bread     100
# dtype: int64

# %% [markdown]
# We can apply operations to specific elements

# %%
print('Original amount', grocery_list['eggs'],'\n')
print('New amount: ',grocery_list['eggs'] + 2)
# Out:
# Original amount 30
#
# New amount:  32

# %%
print('Amount of apples - 2 = ', groceries.iloc[1] - 2)
print('We halve the amount of eggs and apples:\n', groceries.loc[['eggs', 'apples']] / 2)
# Out:
# Amount of apples - 2 =  4
# We halve the amount of eggs and apples:
#  eggs      15
# apples     3
# dtype: object

# %%
wine_df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
print(wine_df.shape)
print(wine_df.ndim)
print(wine_df.size)
print(wine_df.values)
print(wine_df.index)
print(wine_df.columns)
# Out:
# (1599, 12)
# 2
# 19188
# [[ 7.4    0.7    0.    ...  0.56   9.4    5.   ]
#  [ 7.8    0.88   0.    ...  0.68   9.8    5.   ]
#  [ 7.8    0.76   0.04  ...  0.65   9.8    5.   ]
#  ...
#  [ 6.3    0.51   0.13  ...  0.75  11.     6.   ]
#  [ 5.9    0.645  0.12  ...  0.71  10.2    5.   ]
#  [ 6.     0.31   0.47  ...  0.66  11.     6.   ]]
# RangeIndex(start=0, stop=1599, step=1)
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wine_df['fixed acidity'].head()
# Out:
# 0     7.4
# 1     7.8
# 2     7.8
# 3    11.2
# 4     7.4
# Name: fixed acidity, dtype: float64

# %% [markdown]
# It is important to know that when accessing individual elements in a DataFrame, the labels should always be provided with the column label first, i.e. in the form dataframe[column][row].

# %%
wine_df['fixed acidity'][2]
# Out:
# 1599

# %%
#we can modify data 
wine_df['fixed acidity'][2]=9.8 
wine_df.head()
# Out:
# C:\Users\disla\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            9.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#create a new column. Automatically added to end of the dataframe. 
wine_df['ratings'] = wine_df['residual sugar'] + wine_df['citric acid']
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               9.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  ratings
# 0         9.4        5     1.90
# 1         9.8        5     2.60
# 2         9.8        5     2.34
# 3         9.8        6     2.46
# 4         9.4        5     1.90
# ...       ...      ...      ...
# 1594     10.5        5     2.08
# 1595     11.2        6     2.30
# 1596     11.0        6     2.43
# 1597     10.2        5     2.12
# 1598     11.0        6     4.07
#
# [1599 rows x 13 columns]

# %%
#Suppose you want to add a new row, perhaps a new wine
arbor_gold = [{'fixed acidity': 9.1, 'volatile acidity': 0.87, 'citric acid':0.54, 
               'residual sugar': 1.5, 'chlorides': 0.082, 'sulfur dioxide': 12.25, 
              'sulfur dioxide': 44, 'density': 3.26, 'pH':10.21, 'sulphates':0.56, 'alcohol':10.11,
              'quality': 7, 'ratings': 8.2}]
new_df = pd.DataFrame(arbor_gold, index=[1600])
new_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1600            9.1              0.87         0.54             1.5      0.082
#
#       sulfur dioxide  density     pH  sulphates  alcohol  quality  ratings
# 1600              44     3.26  10.21       0.56    10.11        7      8.2

# %%
wine_df = wine_df.append(new_df, sort = "True")
wine_df
#Notice that by appending a new row to the DataFrame, 
#the columns have been put in alphabetical order.

#also i hit append multiple times, sorry
# Out:
#       alcohol  chlorides  citric acid  density  fixed acidity  \
# 0        9.40      0.076         0.00   0.9978            7.4
# 1        9.80      0.098         0.00   0.9968            7.8
# 2        9.80      0.092         0.04   0.9970            9.8
# 3        9.80      0.075         0.56   0.9980           11.2
# 4        9.40      0.076         0.00   0.9978            7.4
# ...       ...        ...          ...      ...            ...
# 1600    10.11      0.082         0.54   3.2600            9.1
# 1600    10.11      0.082         0.54   3.2600            9.1
# 1600    10.11      0.082         0.54   3.2600            9.1
# 1600    10.11      0.082         0.54   3.2600            9.1
# 1600    10.11      0.082         0.54   3.2600            9.1
#
#       free sulfur dioxide     pH  quality  ratings  residual sugar  \
# 0                    11.0   3.51        5     1.90             1.9
# 1                    25.0   3.20        5     2.60             2.6
# 2                    15.0   3.26        5     2.34             2.3
# 3                    17.0   3.16        6     2.46             1.9
# 4                    11.0   3.51        5     1.90             1.9
# ...                   ...    ...      ...      ...             ...
# 1600                  NaN  10.21        7     8.20             1.5
# 1600                  NaN  10.21        7     8.20             1.5
# 1600                  NaN  10.21        7     8.20             1.5
# 1600                  NaN  10.21        7     8.20             1.5
# 1600                  NaN  10.21        7     8.20             1.5
#
#       sulfur dioxide  sulphates  total sulfur dioxide  volatile acidity
# 0                NaN       0.56                  34.0              0.70
# 1                NaN       0.68                  67.0              0.88
# 2                NaN       0.65                  54.0              0.76
# 3                NaN       0.58                  60.0              0.28
# 4                NaN       0.56                  34.0              0.70
# ...              ...        ...                   ...               ...
# 1600            44.0       0.56                   NaN              0.87
# 1600            44.0       0.56                   NaN              0.87
# 1600            44.0       0.56                   NaN              0.87
# 1600            44.0       0.56                   NaN              0.87
# 1600            44.0       0.56                   NaN              0.87
#
# [1607 rows x 14 columns]

# %%
#let's delete a column
wine_df.pop('alcohol') #pop only for deleting columns

# %%
wine_df
# Out:
#       chlorides  citric acid  density  fixed acidity  free sulfur dioxide  \
# 0         0.076         0.00   0.9978            7.4                 11.0
# 1         0.098         0.00   0.9968            7.8                 25.0
# 2         0.092         0.04   0.9970            9.8                 15.0
# 3         0.075         0.56   0.9980           11.2                 17.0
# 4         0.076         0.00   0.9978            7.4                 11.0
# ...         ...          ...      ...            ...                  ...
# 1600      0.082         0.54   3.2600            9.1                  NaN
# 1600      0.082         0.54   3.2600            9.1                  NaN
# 1600      0.082         0.54   3.2600            9.1                  NaN
# 1600      0.082         0.54   3.2600            9.1                  NaN
# 1600      0.082         0.54   3.2600            9.1                  NaN
#
#          pH  quality  ratings  residual sugar  sulfur dioxide  sulphates  \
# 0      3.51        5     1.90             1.9             NaN       0.56
# 1      3.20        5     2.60             2.6             NaN       0.68
# 2      3.26        5     2.34             2.3             NaN       0.65
# 3      3.16        6     2.46             1.9             NaN       0.58
# 4      3.51        5     1.90             1.9             NaN       0.56
# ...     ...      ...      ...             ...             ...        ...
# 1600  10.21        7     8.20             1.5            44.0       0.56
# 1600  10.21        7     8.20             1.5            44.0       0.56
# 1600  10.21        7     8.20             1.5            44.0       0.56
# 1600  10.21        7     8.20             1.5            44.0       0.56
# 1600  10.21        7     8.20             1.5            44.0       0.56
#
#       total sulfur dioxide  volatile acidity
# 0                     34.0              0.70
# 1                     67.0              0.88
# 2                     54.0              0.76
# 3                     60.0              0.28
# 4                     34.0              0.70
# ...                    ...               ...
# 1600                   NaN              0.87
# 1600                   NaN              0.87
# 1600                   NaN              0.87
# 1600                   NaN              0.87
# 1600                   NaN              0.87
#
# [1607 rows x 13 columns]

# %%
#delete a row, use drop
wine_df = wine_df.drop([1600], axis=0)

# %%
wine_df
# Out:
#       chlorides  citric acid  density  fixed acidity  free sulfur dioxide  \
# 0         0.076         0.00  0.99780            7.4                 11.0
# 1         0.098         0.00  0.99680            7.8                 25.0
# 2         0.092         0.04  0.99700            9.8                 15.0
# 3         0.075         0.56  0.99800           11.2                 17.0
# 4         0.076         0.00  0.99780            7.4                 11.0
# ...         ...          ...      ...            ...                  ...
# 1594      0.090         0.08  0.99490            6.2                 32.0
# 1595      0.062         0.10  0.99512            5.9                 39.0
# 1596      0.076         0.13  0.99574            6.3                 29.0
# 1597      0.075         0.12  0.99547            5.9                 32.0
# 1598      0.067         0.47  0.99549            6.0                 18.0
#
#         pH  quality  ratings  residual sugar  sulfur dioxide  sulphates  \
# 0     3.51        5     1.90             1.9             NaN       0.56
# 1     3.20        5     2.60             2.6             NaN       0.68
# 2     3.26        5     2.34             2.3             NaN       0.65
# 3     3.16        6     2.46             1.9             NaN       0.58
# 4     3.51        5     1.90             1.9             NaN       0.56
# ...    ...      ...      ...             ...             ...        ...
# 1594  3.45        5     2.08             2.0             NaN       0.58
# 1595  3.52        6     2.30             2.2             NaN       0.76
# 1596  3.42        6     2.43             2.3             NaN       0.75
# 1597  3.57        5     2.12             2.0             NaN       0.71
# 1598  3.39        6     4.07             3.6             NaN       0.66
#
#       total sulfur dioxide  volatile acidity
# 0                     34.0             0.700
# 1                     67.0             0.880
# 2                     54.0             0.760
# 3                     60.0             0.280
# 4                     34.0             0.700
# ...                    ...               ...
# 1594                  44.0             0.600
# 1595                  51.0             0.550
# 1596                  40.0             0.510
# 1597                  44.0             0.645
# 1598                  42.0             0.310
#
# [1599 rows x 13 columns]

# %% [markdown]
# Lets calculate how many NaN I have. We use isnull().
# In order to count the total number of logical True values we use the .sum() method twice. We have to use it twice because the first sum returns a Pandas Series with the sums of logical True values along columns, as we see below:
# <br>
# If isnull is True, that has numerical value 1 and 0 if false

# %%
wine_df.isnull().sum() #returns a pandaseries
# Out:
# chlorides                  0
# citric acid                0
# density                    0
# fixed acidity              0
# free sulfur dioxide        0
# pH                         0
# quality                    0
# ratings                    0
# residual sugar             0
# sulfur dioxide          1599
# sulphates                  0
# total sulfur dioxide       0
# volatile acidity           0
# dtype: int64

# %%
null = wine_df.isnull().sum().sum()
print(null) #matches with the sulfur dioxide column
# Out:
# 1599

# %%
wine_df.isnull() #True -> null
# Out:
#       chlorides  citric acid  density  fixed acidity  free sulfur dioxide  \
# 0         False        False    False          False                False
# 1         False        False    False          False                False
# 2         False        False    False          False                False
# 3         False        False    False          False                False
# 4         False        False    False          False                False
# ...         ...          ...      ...            ...                  ...
# 1594      False        False    False          False                False
# 1595      False        False    False          False                False
# 1596      False        False    False          False                False
# 1597      False        False    False          False                False
# 1598      False        False    False          False                False
#
#          pH  quality  ratings  residual sugar  sulfur dioxide  sulphates  \
# 0     False    False    False           False            True      False
# 1     False    False    False           False            True      False
# 2     False    False    False           False            True      False
# 3     False    False    False           False            True      False
# 4     False    False    False           False            True      False
# ...     ...      ...      ...             ...             ...        ...
# 1594  False    False    False           False            True      False
# 1595  False    False    False           False            True      False
# 1596  False    False    False           False            True      False
# 1597  False    False    False           False            True      False
# 1598  False    False    False           False            True      False
#
#       total sulfur dioxide  volatile acidity
# 0                    False             False
# 1                    False             False
# 2                    False             False
# 3                    False             False
# 4                    False             False
# ...                    ...               ...
# 1594                 False             False
# 1595                 False             False
# 1596                 False             False
# 1597                 False             False
# 1598                 False             False
#
# [1599 rows x 13 columns]

# %%
#We can count the number of non-NaN values by using .count()
wine_df.count() #returns a pandas series
# Out:
# chlorides               1599
# citric acid             1599
# density                 1599
# fixed acidity           1599
# free sulfur dioxide     1599
# pH                      1599
# quality                 1599
# ratings                 1599
# residual sugar          1599
# sulfur dioxide             0
# sulphates               1599
# total sulfur dioxide    1599
# volatile acidity        1599
# dtype: int64

# %%
#let's drop rows with null values
wine_df.dropna(axis = 0) #rows
# Out:
# Empty DataFrame
# Columns: [chlorides, citric acid, density, fixed acidity, free sulfur dioxide, pH, quality, ratings, residual sugar, sulfur dioxide, sulphates, total sulfur dioxide, volatile acidity]
# Index: []

# %%
wine_df
# Out:
#       chlorides  citric acid  density  fixed acidity  free sulfur dioxide  \
# 0         0.076         0.00  0.99780            7.4                 11.0
# 1         0.098         0.00  0.99680            7.8                 25.0
# 2         0.092         0.04  0.99700            9.8                 15.0
# 3         0.075         0.56  0.99800           11.2                 17.0
# 4         0.076         0.00  0.99780            7.4                 11.0
# ...         ...          ...      ...            ...                  ...
# 1594      0.090         0.08  0.99490            6.2                 32.0
# 1595      0.062         0.10  0.99512            5.9                 39.0
# 1596      0.076         0.13  0.99574            6.3                 29.0
# 1597      0.075         0.12  0.99547            5.9                 32.0
# 1598      0.067         0.47  0.99549            6.0                 18.0
#
#         pH  quality  ratings  residual sugar  sulfur dioxide  sulphates  \
# 0     3.51        5     1.90             1.9             NaN       0.56
# 1     3.20        5     2.60             2.6             NaN       0.68
# 2     3.26        5     2.34             2.3             NaN       0.65
# 3     3.16        6     2.46             1.9             NaN       0.58
# 4     3.51        5     1.90             1.9             NaN       0.56
# ...    ...      ...      ...             ...             ...        ...
# 1594  3.45        5     2.08             2.0             NaN       0.58
# 1595  3.52        6     2.30             2.2             NaN       0.76
# 1596  3.42        6     2.43             2.3             NaN       0.75
# 1597  3.57        5     2.12             2.0             NaN       0.71
# 1598  3.39        6     4.07             3.6             NaN       0.66
#
#       total sulfur dioxide  volatile acidity
# 0                     34.0             0.700
# 1                     67.0             0.880
# 2                     54.0             0.760
# 3                     60.0             0.280
# 4                     34.0             0.700
# ...                    ...               ...
# 1594                  44.0             0.600
# 1595                  51.0             0.550
# 1596                  40.0             0.510
# 1597                  44.0             0.645
# 1598                  42.0             0.310
#
# [1599 rows x 13 columns]

# %%
wine_df.dropna(axis = 1) #drop any column with NaN
# Out:
#       chlorides  citric acid  density  fixed acidity  free sulfur dioxide  \
# 0         0.076         0.00  0.99780            7.4                 11.0
# 1         0.098         0.00  0.99680            7.8                 25.0
# 2         0.092         0.04  0.99700            9.8                 15.0
# 3         0.075         0.56  0.99800           11.2                 17.0
# 4         0.076         0.00  0.99780            7.4                 11.0
# ...         ...          ...      ...            ...                  ...
# 1594      0.090         0.08  0.99490            6.2                 32.0
# 1595      0.062         0.10  0.99512            5.9                 39.0
# 1596      0.076         0.13  0.99574            6.3                 29.0
# 1597      0.075         0.12  0.99547            5.9                 32.0
# 1598      0.067         0.47  0.99549            6.0                 18.0
#
#         pH  quality  ratings  residual sugar  sulphates  total sulfur dioxide  \
# 0     3.51        5     1.90             1.9       0.56                  34.0
# 1     3.20        5     2.60             2.6       0.68                  67.0
# 2     3.26        5     2.34             2.3       0.65                  54.0
# 3     3.16        6     2.46             1.9       0.58                  60.0
# 4     3.51        5     1.90             1.9       0.56                  34.0
# ...    ...      ...      ...             ...        ...                   ...
# 1594  3.45        5     2.08             2.0       0.58                  44.0
# 1595  3.52        6     2.30             2.2       0.76                  51.0
# 1596  3.42        6     2.43             2.3       0.75                  40.0
# 1597  3.57        5     2.12             2.0       0.71                  44.0
# 1598  3.39        6     4.07             3.6       0.66                  42.0
#
#       volatile acidity
# 0                0.700
# 1                0.880
# 2                0.760
# 3                0.280
# 4                0.700
# ...                ...
# 1594             0.600
# 1595             0.550
# 1596             0.510
# 1597             0.645
# 1598             0.310
#
# [1599 rows x 12 columns]

# %%
# We create a list of Python dictionaries
items2 = [{'bikes': 20, 'pants': 30, 'watches': 35, 'shirts': 15, 'shoes':8, 'suits':45},
{'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5, 'shirts': 2, 'shoes':5, 'suits':7},
{'bikes': 20, 'pants': 30, 'watches': 35, 'glasses': 4, 'shoes':10}]

# We create a DataFrame  and provide the row index
store_items = pd.DataFrame(items2, index = ['store 1', 'store 2', 'store 3'])

# We display the DataFrame
store_items
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %% [markdown]
# Let's fill in the NaN values. One way is to use fillna. This is known as forward filling. When replacing NaN values with forward filling, we can use previous values taken from columns or rows. The .fillna(method = 'ffill', axis) will use the forward filling (ffill) method to replace NaN values using the previous known value along the given axis. Let's see some examples:

# %%
store_items.fillna(method = 'ffill', axis = 0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     2.0     10    7.0      4.0

# %%
store_items #for comparison
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
store_items.fillna(method = 'ffill', axis = 1) #fill in value with previous row value
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1   20.0   30.0     35.0    15.0    8.0   45.0     45.0
# store 2   15.0    5.0     10.0     2.0    5.0    7.0     50.0
# store 3   20.0   30.0     35.0    35.0   10.0   10.0      4.0

# %% [markdown]
# Similarly, you can choose to replace the NaN values with the values that go after them in the DataFrame, this is known as backward filling. The .fillna(method = 'backfill', axis) will use the backward filling (backfill) method to replace NaN values using the next known value along the given axis. Just like with forward filling we can choose to use row or column values. Let's see some examples:

# %%
store_items.fillna(method = 'backfill', axis = 0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0     50.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %% [markdown]
# Notice that the NaN value in store 1 has been replaced with the next value in its column. However, notice that the two NaN values in store 3 didn't get replaced. That's because there are no next values in these columns, since these NaN values are the last values in those columns.

# %%
# We replace NaN values by using linear interpolation using column values
store_items.interpolate(method = 'linear', axis = 0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     2.0     10    7.0      4.0

# %%
#Let's go back to the wine dataset
wine_df.isnull().any() #checks if we have any NaN values in our dataset
# Out:
# chlorides               False
# citric acid             False
# density                 False
# fixed acidity           False
# free sulfur dioxide     False
# pH                      False
# quality                 False
# ratings                 False
# residual sugar          False
# sulfur dioxide           True
# sulphates               False
# total sulfur dioxide    False
# volatile acidity        False
# dtype: bool

# %%
wine_df.describe() #gives summary statistics
# Out:
#          chlorides  citric acid      density  fixed acidity  \
# count  1599.000000  1599.000000  1599.000000    1599.000000
# mean      0.087467     0.270976     0.996747       8.320888
# std       0.047065     0.194801     0.001887       1.741441
# min       0.012000     0.000000     0.990070       4.600000
# 25%       0.070000     0.090000     0.995600       7.100000
# 50%       0.079000     0.260000     0.996750       7.900000
# 75%       0.090000     0.420000     0.997835       9.200000
# max       0.611000     1.000000     1.003690      15.900000
#
#        free sulfur dioxide           pH      quality      ratings  \
# count          1599.000000  1599.000000  1599.000000  1599.000000
# mean             15.874922     3.311113     5.636023     2.809781
# std              10.460157     0.154386     0.807569     1.450763
# min               1.000000     2.740000     3.000000     1.200000
# 25%               7.000000     3.210000     5.000000     2.120000
# 50%              14.000000     3.310000     6.000000     2.450000
# 75%              21.000000     3.400000     6.000000     2.940000
# max              72.000000     4.010000     8.000000    15.890000
#
#        residual sugar  sulfur dioxide    sulphates  total sulfur dioxide  \
# count     1599.000000             0.0  1599.000000           1599.000000
# mean         2.538806             NaN     0.658149             46.467792
# std          1.409928             NaN     0.169507             32.895324
# min          0.900000             NaN     0.330000              6.000000
# 25%          1.900000             NaN     0.550000             22.000000
# 50%          2.200000             NaN     0.620000             38.000000
# 75%          2.600000             NaN     0.730000             62.000000
# max         15.500000             NaN     2.000000            289.000000
#
#        volatile acidity
# count       1599.000000
# mean           0.527821
# std            0.179060
# min            0.120000
# 25%            0.390000
# 50%            0.520000
# 75%            0.640000
# max            1.580000

# %%
#can apply describe just for one column
wine_df['chlorides'].describe()
# Out:
# count    1599.000000
# mean        0.087467
# std         0.047065
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
print('Maximum values of each column:\n', wine_df.max())
# Out:
# Maximum values of each column:
#  chlorides                 0.61100
# citric acid               1.00000
# density                   1.00369
# fixed acidity            15.90000
# free sulfur dioxide      72.00000
# pH                        4.01000
# quality                   8.00000
# ratings                  15.89000
# residual sugar           15.50000
# sulfur dioxide                NaN
# sulphates                 2.00000
# total sulfur dioxide    289.00000
# volatile acidity          1.58000
# dtype: float64

# %%
print('Average value of each column:\n', wine_df.mean())
# Out:
# Average value of each column:
#  chlorides                0.087467
# citric acid              0.270976
# density                  0.996747
# fixed acidity            8.320888
# free sulfur dioxide     15.874922
# pH                       3.311113
# quality                  5.636023
# ratings                  2.809781
# residual sugar           2.538806
# sulfur dioxide                NaN
# sulphates                0.658149
# total sulfur dioxide    46.467792
# volatile acidity         0.527821
# dtype: float64

# %%
wine_df.corr()
# Out:
#                       chlorides  citric acid   density  fixed acidity  \
# chlorides              1.000000     0.203823  0.200632       0.093756
# citric acid            0.203823     1.000000  0.364947       0.670718
# density                0.200632     0.364947  1.000000       0.668011
# fixed acidity          0.093756     0.670718  0.668011       1.000000
# free sulfur dioxide    0.005562    -0.060978 -0.021946      -0.153824
# pH                    -0.265026    -0.541904 -0.341699      -0.683081
# quality               -0.128907     0.226373 -0.174919       0.123461
# ratings                0.081413     0.273811  0.394286       0.201466
# residual sugar         0.055610     0.143577  0.355283       0.114632
# sulfur dioxide              NaN          NaN       NaN            NaN
# sulphates              0.371260     0.312770  0.148506       0.182935
# total sulfur dioxide   0.047400     0.035533  0.071269      -0.112994
# volatile acidity       0.061298    -0.552496  0.022026      -0.255148
#
#                       free sulfur dioxide        pH   quality   ratings  \
# chlorides                        0.005562 -0.265026 -0.128907  0.081413
# citric acid                     -0.060978 -0.541904  0.226373  0.273811
# density                         -0.021946 -0.341699 -0.174919  0.394286
# fixed acidity                   -0.153824 -0.683081  0.123461  0.201466
# free sulfur dioxide              1.000000  0.070377 -0.050656  0.173596
# pH                               0.070377  1.000000 -0.057731 -0.156006
# quality                         -0.050656 -0.057731  1.000000  0.043741
# ratings                          0.173596 -0.156006  0.043741  1.000000
# residual sugar                   0.187049 -0.085652  0.013732  0.991132
# sulfur dioxide                        NaN       NaN       NaN       NaN
# sulphates                        0.051658 -0.196648  0.251397  0.047369
# total sulfur dioxide             0.667666 -0.066495 -0.185100  0.202084
# volatile acidity                -0.010504  0.234937 -0.390558 -0.072322
#
#                       residual sugar  sulfur dioxide  sulphates  \
# chlorides                   0.055610             NaN   0.371260
# citric acid                 0.143577             NaN   0.312770
# density                     0.355283             NaN   0.148506
# fixed acidity               0.114632             NaN   0.182935
# free sulfur dioxide         0.187049             NaN   0.051658
# pH                         -0.085652             NaN  -0.196648
# quality                     0.013732             NaN   0.251397
# ratings                     0.991132             NaN   0.047369
# residual sugar              1.000000             NaN   0.005527
# sulfur dioxide                   NaN             NaN        NaN
# sulphates                   0.005527             NaN   1.000000
# total sulfur dioxide        0.203028             NaN   0.042947
# volatile acidity            0.001918             NaN  -0.260987
#
#                       total sulfur dioxide  volatile acidity
# chlorides                         0.047400          0.061298
# citric acid                       0.035533         -0.552496
# density                           0.071269          0.022026
# fixed acidity                    -0.112994         -0.255148
# free sulfur dioxide               0.667666         -0.010504
# pH                               -0.066495          0.234937
# quality                          -0.185100         -0.390558
# ratings                           0.202084         -0.072322
# residual sugar                    0.203028          0.001918
# sulfur dioxide                         NaN               NaN
# sulphates                         0.042947         -0.260987
# total sulfur dioxide              1.000000          0.076470
# volatile acidity                  0.076470          1.000000

# %% [markdown]
# # Groupby #

# %% [markdown]
# You call .groupby() and pass the name of the column you want to group on, which is "residual sugar". Then, you use ["pH"] to specify the columns on which you want to perform the actual aggregation.

# %%
#let's group the residual sugar levels with pH
wine_df.groupby(['residual sugar'])['pH'].count()
# Out:
# residual sugar
# 0.9      2
# 1.2      8
# 1.3      5
# 1.4     35
# 1.5     30
#         ..
# 13.4     1
# 13.8     2
# 13.9     1
# 15.4     2
# 15.5     1
# Name: pH, Length: 91, dtype: int64
